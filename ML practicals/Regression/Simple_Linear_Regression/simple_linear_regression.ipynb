# %% [markdown]
# ## Question
#
# Regression: Simple Linear
#
# Dataset: 1.01. Simple linear regression
#
# Apply Data pre-processing (Label Encoding , Data Transformation….)
#
# techniques if necessary.
#
# Explore the relationship between students SAT score and GPA using
#
# linear regression model. Also display the regression results and plot the
#
# regression line

# %% [markdown]
# Frequency of question : 1

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
dataset = pd.read_csv("1.01. Simple linear regression.csv")

# %%
dataset.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values

# %%
dataset.shape
# Out:
# (84, 2)

# %%
dataset.isna().sum()
# Out:
# SAT    0
# GPA    0
# dtype: int64

# %%
plt.scatter(X,y)

# %% [markdown]
# ## Splitting the Dataset into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %% [markdown]
# ## Training the Simple Linear Regression Model on the Training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# ## Regression Line

# %%
plt.scatter(X_test, y_test, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('SAT Score')
plt.ylabel('GPA')
plt.title('Linear Regression: SAT Score vs. GPA')
plt.show()

# %%
plt.scatter(X_train, y_train, color='black')
plt.plot(X_train, regressor.predict(X_train), color='blue', linewidth=3)
plt.xlabel('SAT Score')
plt.ylabel('GPA')
plt.title('Linear Regression: SAT Score vs. GPA')
plt.show()

# %% [markdown]
# ## Regression Results

# %%
from sklearn import metrics

# %%
print('Coefficients:', regressor.coef_)
print('Intercept:', regressor.intercept_)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Coefficients: [0.00171033]
# Intercept: 0.16586478019104378
# Mean Absolute Error: 0.14375509721383473
# Mean Squared Error: 0.04691776855623536
# Root Mean Squared Error: 0.2166050981769251

# %% [markdown]
# # From the results of the linear regression analysis, the following conclusions can be drawn:
#
# ### Coefficients:
#
# The coefficient for the SAT score is approximately 0.0017. This implies that, on average, for a one-unit increase in SAT score, the
#
# predicted GPA increases by 0.0017 units.
#
#
# ### Intercept:
#
# The intercept is approximately 0.166. This is the predicted GPA when the SAT score is zero. However, since SAT scores are not zero in
#
# reality, the interpretation of the intercept in this context might not have a meaningful interpretation.
#
#
# ### Mean Absolute Error (MAE):
#
# The mean absolute error measures the average absolute difference between the actual and predicted values. In this case, the MAE is
#
# approximately 0.144. Lower values of MAE indicate better model performance, so a MAE of 0.144 suggests a relatively small average
#
# prediction error.
#
#
# ### Mean Squared Error (MSE):
#
# The mean squared error measures the average of the squared differences between actual and predicted values. In this case, the MSE is
#
# approximately 0.047. Similar to MAE, lower values of MSE indicate better model performance.
#
#
# ### Root Mean Squared Error (RMSE):
#
# The root mean squared error is the square root of the mean squared error. It provides a similar measure to the standard deviation of the
#
# residuals. The RMSE here is approximately 0.217, indicating the average prediction error in the same units as the dependent variable (GPA).
#
#
#
# Overall, the model seems to have a relatively small prediction error based on the MAE, MSE, and RMSE values.
